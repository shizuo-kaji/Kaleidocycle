# %% [markdown]
# # Kaleidocycle Exploration

# %%
# %matplotlib widget
import sys
import os

# Add parent src directory to path
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '../src')))

import numpy as np
import matplotlib.pyplot as plt

# Import kaleidocycle functions
from kaleidocycle import *
from kaleidocycle.backends import set_backend, get_available_backends

# Try to use jax backend if available
# numpy is faster for small scale problems, so default to numpy
# jax is more precise
backend = 'numpy' # 'numpy' or 'jax'

if backend == 'jax' and 'jax' in get_available_backends():
    set_backend('jax')
    print("using jax backend")
else:
    set_backend('numpy')
    print("using numpy backend")

# Set up output directory
output_dir = 'output'
os.makedirs(output_dir, exist_ok=True)
# Out:
# using numpy backend

# %% [markdown]
# ## Find Kaleidocycles via Optimization
#
# Conjecture: When non-oriented or odd n, the minimisers of bending attain the extremum of the torsion.

# %%
# Set parameters for optimization
# note: objective 'mean_cos' is meaningless with oriented n:even or non-oriented n:odd (always -1.0)
#       objective 'neg_mean_cos' is meaningless with oriented (always 1.0)

n=7
oriented=False
objective = 'bending' # 'neg_mean_cos' # 'mean_cos', 'bending', 'curvature_recursion'
seed=19 # random seed for initial configuration
maxiter=15000 # maximum number of iterations for optimizer
filename = None # "kaleidocycle_k10_oriented_bending.json" # set to None to generate random initial configuration

if filename is not None and os.path.exists(os.path.join(output_dir, filename)):
    filepath = os.path.join(output_dir, filename)
    print(f"Importing from {filepath}")
    kc = import_json(filepath)
    print("Initial configuration:")
    print(kc.report())
    initial = kc.hinges
    config = kc.config
    oriented = kc.oriented
else:
    print("Generating random initial configuration")
    initial = random_hinges(n, seed=seed, oriented=oriented).as_array()
    config = ConstraintConfig(oriented=oriented, enforce_anchors=False, constant_torsion=True)

# Use the built-in optimizer to minimize the objective function
result = optimize_cycle(
    initial,
    config,
    objective=objective,
    options=SolverOptions(maxiter=maxiter, penalty_weight=10000.0, use_constraint_solver=True),
)

print(f"success flag: {result.success}")
if not result.success:
    print(f"  message: {result.result.message}")
print(f"Objective value: {result.result.fun:.6f}")

# create Kaleidocycle object from optimized hinges
kc = Kaleidocycle(hinges=result.hinges)

print("\n" + format_report(result.hinges, config))
# Out:
# Generating random initial configuration
# /opt/homebrew/Caskroom/miniforge/base/envs/py313/lib/python3.13/site-packages/scipy/optimize/_trustregion_constr/equality_constrained_sqp.py:81: UserWarning: Singular Jacobian matrix. Using SVD decomposition to perform the factorizations.
#   Z, LS, Y = projections(A, factorization_method)
# /opt/homebrew/Caskroom/miniforge/base/envs/py313/lib/python3.13/site-packages/scipy/optimize/_differentiable_functions.py:552: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   self.H.update(delta_x, delta_g)
# /opt/homebrew/Caskroom/miniforge/base/envs/py313/lib/python3.13/site-packages/scipy/optimize/_trustregion_constr/equality_constrained_sqp.py:217: UserWarning: Singular Jacobian matrix. Using SVD decomposition to perform the factorizations.
#   Z, LS, Y = projections(A, factorization_method)
# success flag: True
# Objective value: 3.341276
#
# Kaleidocycle Property Report
# ============================
# Number of hinges (N): 7
# Oriented: False
# Penalty: 1.2017802853e-31
# First and last hinges: (0.5789179389, -0.0406429361, 0.8143722562), (-0.5789179389, 0.0406429361, -0.8143722562)
#
# --- Geometric Properties ---
# Mean pairwise cosine: 0.2953885638
# Std dev of cosines: 8.1260004804e-17
# Mean curvature: -0.2009110437
# Mean torsion: 1.2709341213
# Mean curvature recursion: -1.4884369642e+00
# Std dev curvature recursion: 1.2435783379e-06
# Computed axis: [0.402449491  1.1991857213 0.2384373284]
#
# --- Topological Properties ---
# Writhe: 0.1681437316
# Total Twist (Tw/π): 2.8318562684
# Linking Number (Lk = Tw + Wr): 3.0000000000
#
# --- Constraint Violations ---
# Configuration: ConstraintConfig(slide=0.0, oriented=False, enforce_anchors=False, constant_torsion=True, alignment=True, closure=True, reference_torsion=None, target_linking=None, curvature_recursion=False)
#   - unit_norm: max_abs=2.2204460493e-16, sum_sq=8.6281661509e-32
#   - closure: max_abs=1.1102230246e-16, sum_sq=2.4651903288e-32
#   - constant_torsion: max_abs=5.5511151231e-17, sum_sq=9.2444637331e-33
#   - alignment: max_abs=0.0000000000e+00, sum_sq=0.0000000000e+00
# Total Penalty (sum_sq): 1.2017802853e-31
#
# --- Energy ---
# Bending Energy: 3.3412760457e+00
# Dipole Energy: 4.5581220879e-01
# Torsion Energy: 3.0403553682e+00

# %%
#kc = Kaleidocycle(n=7)
B,T = from_curvatures_and_cos(kc.curvatures, kc.mean_cosine, initial_binormal=kc.hinges[0], initial_tangent=kc.tangents[0])
np.allclose(T, kc.tangents),np.allclose(B, kc.hinges)
# Out:
# (True, True)

# %%
result

# %%
kc.is_stationary('mean_cos', tolerance=1e-4)
kc.is_stationary('bending', tolerance=1e-4)

# %%
# plot curvature of each vertex
plot_vertex_values(kc.curvatures)
plt.show()

# %%
# plot the kaleidocycle
kc.plot()

# %%
# Multiple seed optimization example
n = 8
oriented = False
objective = 'curvature_recursion' # "bending"

config = ConstraintConfig(oriented=oriented, enforce_anchors=False, constant_torsion=True)
results, df = optimize_multi_seed(
    n, config, n_trials=8, objective=objective, return_dataframe=True
)
df

# %%
print(results[1].report())

# %%
results[0].is_stationary('mean_cos', tolerance=1e-4)

# %%
results[5].plot()

# %% [markdown]
# ## Curvature and Torsion Reconstruction

# %%
# Minimize bending energy over curvature space
result = optimize_curvature_torsion(
    n=8,
    oriented=False,
    objective="curvature_recursion",
)

kc = Kaleidocycle(hinges=result.hinges)
print(kc.report())
# Out:
# Kaleidocycle Property Report
# ============================
# Number of hinges (N): 8
# Oriented: False
# Penalty: 1.272313e-28
# First and last hinges: (0.000000, 0.000000, 1.000000), (0.000000, -0.000000, -1.000000)
#
# --- Geometric Properties ---
# Mean pairwise cosine: -0.060181
# Std dev of cosines: 5.496638e-17
# Mean curvature: -0.510614
# Mean torsion: 1.631014
# Mean curvature recursion: -5.213410e-01
# Std dev curvature recursion: 1.264497e+01
# Computed axis: [-1.656542  0.920007 -2.710988]
#
# --- Topological Properties ---
# Writhe: 0.846658
# Total Twist (Tw/π): 4.153342
# Linking Number (Lk = Tw + Wr): 5.000000
#
# --- Constraint Violations ---
# Configuration: ConstraintConfig(slide=0.0, oriented=np.False_, enforce_anchors=False, constant_torsion=True, alignment=True, closure=True, reference_torsion=None, target_linking=None, curvature_recursion=False)
#   - unit_norm: max_abs=4.440892e-15, sum_sq=2.356722e-29
#   - closure: max_abs=4.773959e-15, sum_sq=5.824404e-29
#   - constant_torsion: max_abs=2.706169e-16, sum_sq=9.716317e-32
#   - alignment: max_abs=4.815592e-15, sum_sq=4.532291e-29
# Total Penalty (sum_sq): 1.272313e-28
#
# --- Energy ---
# Bending Energy: 8.938535e+00
# Dipole Energy: 6.014272e+00
# Torsion Energy: 6.041720e+00

# %%
#kc.plot()
print("is stationary:", kc.is_stationary('mean_cos', tolerance=1e-4))
# Out:
# is stationary: {'is_stationary': False, 'projected_gradient_norm': 0.09458666016001413, 'gradient_norm': 0.5281229391271721, 'constraint_penalty': 8.079410889675716e-30, 'details': {'energy': 'mean_cos', 'tolerance': 0.0001, 'finite_diff_step': 1e-08, 'n_constraints': 22, 'n_variables': 27, 'constraint_rank': 21, 'backend': 'default'}}

# %%
result
# Out:
# OptimizationSummary(hinges=array([[ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00],
#        [ 4.03433632e-07, -0.00000000e+00, -1.00000000e+00],
#        [-7.91741096e-07,  1.09434954e-07,  1.00000000e+00],
#        [ 3.90520875e-07, -1.51637206e-07, -1.00000000e+00],
#        [-1.66179209e-07,  4.86942309e-07,  1.00000000e+00],
#        [-9.93037198e-08, -7.90714444e-07, -1.00000000e+00],
#        [-3.61729123e-09,  4.00629888e-07,  1.00000000e+00],
#        [ 2.12628165e-09,  2.80098877e-09, -1.00000000e+00]]), energy=-0.9999999999999185, penalty=2.4733223608184323e-17, _scipy_result=          message: `gtol` termination condition is satisfied.
#           success: True
#            status: 1
#               fun: -0.9999999999999185
#                 x: [ 1.611e+00  2.747e-01 -9.045e+00 -7.160e+00 -1.286e-01
#                      8.965e+00  2.617e-01  3.142e+00]
#               nit: 17
#              nfev: 153
#              njev: 17
#              nhev: 0
#          cg_niter: 25
#      cg_stop_cond: 1
#              grad: [ 0.000e+00  0.000e+00 -0.000e+00 -0.000e+00 -0.000e+00
#                      0.000e+00  0.000e+00 -3.795e-07]
#   lagrangian_grad: [ 0.000e+00 -7.404e-19 -2.369e-14 -2.768e-14  2.956e-14
#                      3.094e-14  2.109e-14  1.735e-18]
#            constr: [array([-2.801e-09,  2.126e-09,  4.227e-13]), array([ 2.126e-09,  2.801e-09,  0.000e+00])]
#               jac: [array([[ 0.000e+00, -4.013e-07, ...,  1.491e-09,
#                             6.932e-03],
#                           [ 0.000e+00,  2.801e-09, ..., -4.034e-07,
#                            -5.262e-03],
#                           [ 0.000e+00, -1.619e-13, ...,  1.616e-13,
#                            -1.971e-06]]), array([[ 0.000e+00,  2.801e-09, ..., -4.034e-07,
#                            -5.262e-03],
#                           [ 0.000e+00,  4.013e-07, ..., -1.491e-09,
#                            -6.932e-03],
#                           [ 0.000e+00,  0.000e+00, ...,  0.000e+00,
#                             0.000e+00]])]
#       constr_nfev: [153, 153]
#       constr_njev: [0, 0]
#       constr_nhev: [0, 0]
#                 v: [array([-1.698e+00, -5.203e-06, -1.918e-01]), array([ 5.075e-06, -1.698e+00, -0.000e+00])]
#            method: equality_constrained_sqp
#        optimality: 3.093825598986934e-14
#  constr_violation: 2.8009887676076034e-09
#    execution_time: 0.10120487213134766
#         tr_radius: 2.3629094302479907
#    constr_penalty: 42651988773.27184
#             niter: 17, _jaxopt_result=None)

# %% [markdown]
# ## Export and Import Kaleidocycle Configurations
#
# Save and load kaleidocycle configurations in JSON (full data) or CSV (hinges only) formats.

# %%
# Example: Export and import an optimized kaleidocycle
print(f"Optimized n={n} kaleidocycle")
oriented_str = 'oriented' if oriented else 'nonoriented'
filename = f'kaleidocycle_k{n}_{oriented_str}_{objective}'

# Export to JSON (all data)
export_json(kc, os.path.join(output_dir, filename+'.json'))
print(f"\n✓ Exported to {os.path.join(output_dir, filename)}.json")

# Export to CSV (hinges only)
export_csv(
    result.hinges,
    os.path.join(output_dir, filename+'.csv'),
    header=True,
)
print(f"✓ Exported to {os.path.join(output_dir, filename)}.csv includes hinges only (n+1 rows × 3 columns)")

# %%
# Import from JSON
kc = import_json(os.path.join(output_dir, filename+'.json'))
print(kc.report())

# Import from CSV
loaded_csv = import_csv(os.path.join(output_dir, filename+'.csv'))

print(f"\nLoaded from CSV:")
print(f"  hinges shape: {loaded_csv.shape}")
print(f"  n = {loaded_csv.shape[0] - 1}")

# Verify they match
if np.allclose(kc.hinges, loaded_csv):
    print("\n✓ JSON and CSV hinges match!")
else:
    print("\n✗ Warning: JSON and CSV hinges don't match")

# %% [markdown]
# ## Transformations

# %%
# Transformations example
kc2 = transform_kaleidocycle(kc, "subdivide", divisions=3)
kc2.plot()
print(kc2.report())

# %% [markdown]
# ## Hinge manipulation (without using Kaleidocycle class)

# %%
binormals = result.hinges
# Compute mid-axes (tangent vectors)
tangents = binormals_to_tangents(binormals)
print(f"Tangent vectors: {tangents.shape}")

# Compute curve (accumulated positions)
curve = tangents_to_curve(tangents)
print(f"curve points: {curve.shape}")
print(f"first and last curve difference (should be close to zero): {np.linalg.norm(curve[-1]-curve[0])}")

# Compute curvature
curvature = pairwise_curvature(binormals, signed=True)
print(f"\nCurvature values (radians):")
print(curvature)
print(f"Curvature (degrees): {np.degrees(curvature)}")
print(f"Mean curvature: {np.degrees(np.mean(curvature)):.2f}°")

# Compute torsion
torsion = pairwise_cosines(binormals)
print(f"\nTorsion values (cosine):")
print(f"Mean torsion: {(np.mean(torsion)):.6f}")
print(f"Std torsion: {(np.std(torsion)):.6f}")

# %%
# Compute and visualize the optimized curve
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 6), subplot_kw={'projection': '3d'})

plot_curve(curve, ax=ax1, title='curve', color='forestgreen')

# Plot band structure
plot_band(
    curve,
    binormals,
    ax=ax2,
    width=0.15,
    title='Optimized Band',
    facecolor='lightcoral',
    edgecolor='darkred',
    alpha=0.7,
)

plt.tight_layout()
plt.show()

# %%
# Use subset of binormals and curvature
axis = compute_axis(binormals[:4], curvature[:3])

print("Rotation Axis:")
print(f"  A = [{axis[0]:.4f}, {axis[1]:.4f}, {axis[2]:.4f}]")
print(f"  |A| = {np.linalg.norm(axis):.4f}")
print(f"\nNormalized: [{axis[0]/np.linalg.norm(axis):.4f}, "
        f"{axis[1]/np.linalg.norm(axis):.4f}, "
        f"{axis[2]/np.linalg.norm(axis):.4f}]")

# Verify: A · B[i] should equal tan(K[i]/2)
print("\nVerification (A · B[i] = tan(K[i]/2)):")
for i in range(len(binormals)-1):
    lhs = np.dot(axis, binormals[i])
    rhs = np.tan(curvature[i] / 2)
    print(f"  i={i}: {lhs:.6f} ≈ {rhs:.6f} (diff={abs(lhs-rhs):.2e})")

# %% [markdown]
# ## Constrained Optimization with Lk
#
# Conjecture: Local minima share similar properties to Mobius kaleidocycles.

# %%
n=9
oriented =  True
seed = 4
objective = "bending" # "bending"
target_linking =4

config = ConstraintConfig(oriented=oriented, target_linking=target_linking, constant_torsion=True, enforce_anchors=False)
initial_binormals = random_hinges(n, seed=seed, oriented=oriented).as_array()
result = optimize_with_linking_constraint(
    initial_binormals,
    config=config,
    objective=objective,
)

final_lk = compute_linking_number(result.hinges)
print(f"Achieved: {final_lk:.3f}π, Energy: {result.energy:.3f}")
if abs(final_lk - target_linking) < 1e-3:
    print("Target linking number achieved!")
    print("\n" + format_report(result.hinges, config))
else:
    print("Target linking number not achieved.")

# %%
kc = Kaleidocycle(hinges=result.hinges)
print(kc.config)
print(kc.is_stationary('mean_cos', tolerance=1e-4))
print("\n" + format_report(result.hinges, config))

# %%
# Export to JSON (all data)
oriented_str = 'oriented' if oriented else 'nonoriented'
filename = f'kaleidocycle_k{n}_{oriented_str}_{objective}_lk{target_linking}'
export_json(kc, os.path.join(output_dir, filename+'.json'))
print(f"\n✓ Exported to {os.path.join(output_dir, filename)}.json")

# %%
# plot result
kc = Kaleidocycle(hinges=result.hinges)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 6), subplot_kw={'projection': '3d'})

plot_curve(kc.curve, ax=ax1)
kc.plot(ax=ax2)

plt.tight_layout()
plt.show()

# %%
# Multiple seed optimization example
n = 8
oriented = True
objective = "bending"
target_linking = 4

config = ConstraintConfig(oriented=oriented, target_linking=target_linking, enforce_anchors=False, constant_torsion=True)
results, df = optimize_multi_seed(
    n, config, n_trials=5, objective=objective, return_dataframe=True
)
df

# %%
results[4].plot()

# %% [markdown]
# ## Generate paper model

# %%
ax = paper_model(
    result.hinges,
    facecolors=["lightblue", "lightcoral", "lightgreen"],
    edgecolor="black",
    linewidth=2.0,
    alpha=0.5,
)

plt.savefig(os.path.join(output_dir, "paper_template.png"))
plt.show()
