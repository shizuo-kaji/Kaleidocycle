# %% [markdown]
# # Motion of Kaleidocycle

# %%
# %matplotlib widget
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import os

# Import kaleidocycle functions
from kaleidocycle import *

# Set random seed for reproducibility
np.random.seed(42)

# Configure matplotlib
plt.rcParams['figure.figsize'] = (12, 4)
plt.rcParams['figure.dpi'] = 100

# Set up output directory
output_dir = 'output'
os.makedirs(output_dir, exist_ok=True)

# %%
# Load kaleidocycle data from JSON
#filename = 'kaleidocycle_k8_nonoriented_neg_mean_cos.json'
#filename = 'kaleidocycle_k8_nonoriented_bending.json'
filename = 'kaleidocycle_k9_oriented_bending.json'
#filename = 'kaleidocycle_k9_oriented_mean_cos.json'
#filename = 'kaleidocycle_k9_oriented_lk4_bending.json'
try:
    filepath = os.path.join(output_dir, filename)
    if filename.lower().endswith('.json'):
        kc = import_json(filepath)
        config = ConstraintConfig(oriented=kc.oriented, enforce_anchors=False, constant_torsion=True, alignment=True, reference_torsion=kc.mean_cosine)
        binormals = kc.hinges
    else:
        binormals = import_csv(filepath)
        config = ConstraintConfig(oriented=is_oriented(binormals), enforce_anchors=False, constant_torsion=True, alignment=True)
except Exception as e:
    print(f"Error loading file {filename} from {output_dir}: {e}")
    kc = Kaleidocycle(8, oriented=False)
    binormals = kc.hinges
    config = kc.config
config.reference_torsion = mean_cosine(binormals)
print(format_report(binormals, config))

# %%
num_frames = 100
step_size = 0.05
rule = "step" # "mKdV", "mKdV2", "sine_gordon", "random", "step" #

frames = generate_animation(kc.hinges, num_frames=num_frames, step_size=step_size, rule=rule, oriented=kc.oriented, config=config)

# Create animation
anim = KaleidocycleAnimation(
    frames=frames,
    evolution_rule=rule,
    metadata={"step_size": step_size}
)

# align frames
anim.align()

# Compute properties
anim.compute_vertex_property("curvature")
anim.compute_scalar_property("penalty")
anim.compute_scalar_property("bending_energy")
anim.compute_scalar_property("mean_torsion")
anim.compute_scalar_property("mean_curvature")
anim.compute_scalar_property("cos_invariant", func=lambda x: cos_invariant(pairwise_curvature(x), oriented=kc.oriented))
plt.close('all')

fig, axes = plt.subplots(5, 1, figsize=(10, 9))

# Plot bending energy
axes[0].plot(anim.scalar_properties["bending_energy"], 'b-o', linewidth=2, markersize=4)
axes[0].set_ylabel("Bending Energy", fontsize=12)
axes[0].set_title("Scalar Properties Evolution", fontsize=14, fontweight='bold')
axes[0].grid(True, alpha=0.3)

# Plot mean torsion
axes[1].plot(anim.scalar_properties["mean_torsion"], 'r-o', linewidth=2, markersize=4)
axes[1].set_ylabel("Mean Torsion", fontsize=12)
axes[1].grid(True, alpha=0.3)

# Plot mean curvature
axes[2].plot(anim.scalar_properties["mean_curvature"], 'g-o', linewidth=2, markersize=4)
axes[2].set_xlabel("Frame", fontsize=12)
axes[2].set_ylabel("Mean Curvature", fontsize=12)
axes[2].grid(True, alpha=0.3)

# Plot penalty
axes[3].plot(anim.scalar_properties["penalty"], 'm-o', linewidth=2, markersize=4)
axes[3].set_xlabel("Frame", fontsize=12)
axes[3].set_ylabel("Penalty", fontsize=12)
axes[3].grid(True, alpha=0.3)

# Plot cos invariant
axes[4].plot(anim.scalar_properties["cos_invariant"], 'c-o', linewidth=2, markersize=4)
axes[4].set_xlabel("Frame", fontsize=12)
axes[4].set_ylabel("Cosine Invariant", fontsize=12)
axes[4].grid(True, alpha=0.3)

plt.tight_layout()
#plt.savefig("examples/simple_scalar_plot.png", dpi=150, bbox_inches='tight')
#print("\nPlot saved to: examples/simple_scalar_plot.png")
plt.show()

# %%
fig, ani = plot_band(
      animation=anim,
      scalar_properties=["penalty", "bending_energy","mean_torsion"],
  )

# %%
print(format_report(frames[80], config))

# %%
anim.is_closed, anim.is_aligned, anim.oriented

# %% [markdown]
# ## Cleaning and Aligning Animation Frames
#
# We can filter out infeasible frames and remove spurious global rotations.

# %%
# Clean frames
cleaned, kept_indices = clean_animation_frames(
    frames,
    config=config,
    tolerance=0.05,
    fix_twist=True,
    check_torsion=False,
)

print(f"Frames after cleaning: {len(cleaned)}/{len(frames)}")
print(f"Kept indices: {kept_indices[:10]}...")

# Align frames to remove global rotation
aligned = align_animation_frames(cleaned, use_barycentre=True)
print(f"Frames aligned: {len(aligned)}")

# Measure alignment quality
var_before = np.std([np.linalg.norm(f - cleaned[0]) for f in cleaned])
var_after = np.std([np.linalg.norm(f - aligned[0]) for f in aligned])

print(f"\nVariation before alignment: {var_before:.4f}")
print(f"Variation after alignment:  {var_after:.4f}")
print(f"Improvement: {(1 - var_after/var_before)*100:.1f}%")

# %%
anim_aligned = KaleidocycleAnimation(frames=aligned)
fig, ani = plot_band(
      animation=anim_aligned
  )
