# %% [markdown]
# # Theta Function Animation Demo
#
# This notebook demonstrates kaleidocycle animation using exact analytic solutions from Jacobi theta functions.
#
# Please look at the following paper for details:
# - Shizuo Kaji, Kenji Kajiwara, Shota Shigetomi,
#   [*An explicit construction of Kaleidocycles*](https://arxiv.org/abs/2308.04977)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.animation import FuncAnimation
from IPython.display import HTML


from kaleidocycle import (
    Kaleidocycle,
    KaleidocycleAnimation,
    plot_band,
    generate_theta_curve,
    generate_animation_theta,
    generate_theta_binormals,
    solve_closure_conditions,
    binormals_to_tangents,
    curve_to_binormals,
    tangents_to_curve,
    pairwise_cosines,
    compute_torsion,
    writhe,
    total_twist,
    format_report,
)

# %matplotlib widget
plt.rcParams['figure.figsize'] = (12, 8)

# %% [markdown]
# ## Closure Condition Solver

# %%
# Import closure condition solver
from kaleidocycle import solve_closure_conditions
from kaleidocycle.theta import close1, close2

# Test cases: N values for different kaleidocycles
# Initial guess (N, m, (v, r)) only - y is computed from y = N*v/m
test_cases = [
    (6, 3, (0.64, 0.27)),
    (7, 3, (0.48, 0.27)),
    (8, 3, (0.40, 0.72)),
    (9, 3, (0.34, 0.29)),
    (15, 3, (0.19, 0.30)),
    (15, 5, (0.40, 0.69)),
#    (38, 3, (0.07, 0.30)),
]

print("="*80)
print("CLOSURE CONDITION SOLVER: Finding Parameters for Different N")
print("="*80)
print()

solutions = []

for N, m, initial_guess in test_cases:
    print(f"N = {N} tetrahedra with m = {m}:")
    print(f"  Solving with initial guess: v={initial_guess[0]:.2f}, r={initial_guess[1]:.2f}")

    result = solve_closure_conditions(N, m=m, initial_guess=initial_guess)

    if result:
        v, r, y = result
        solutions.append((N, m, v, r, y))

        print(f"  ✓ Solution found:")
        print(f"    v = {v:.10f}")
        print(f"    r = {r:.10f}")
        print(f"    y = {y:.10f}")

        # Verify closing conditions with new signature: close1(v, r, k, m)
        c1 = close1(v, r, N, m)
        c2 = close2(v, r, N, m)

        print(f"  Verification:")
        print(f"    |close1| = {abs(c1):.2e}")
        print(f"    |close2| = {abs(c2):.2e}")

        # Generate and check binormals
        try:
            #binormals = generate_theta_binormals(v, 0, r, y, N, t=0.0)
            curve = generate_theta_curve(v, 0, r, y, N, t=0.0)
            kc=Kaleidocycle(curve=curve)
            cosines = pairwise_cosines(kc.hinges)
            torsion_vals = compute_torsion(kc.hinges)

            print(f"  Kaleidocycle properties:")
            print(f"    Constant torsion: mean(cos)={np.mean(cosines):.8f}, std={np.std(cosines):.2e}")
            print(f"    Mean torsion angle: {np.degrees(np.mean(torsion_vals)):.4f}°")
            print(f"    Stationary: {kc.is_stationary('mean_cos', tolerance=1e-4)}")
        except Exception as e:
            print(f"    Warning: {e}")
    else:
        print(f"  ✗ No solution found")

    print()
# Out:
# ================================================================================
# CLOSURE CONDITION SOLVER: Finding Parameters for Different N
# ================================================================================
#
# N = 6 tetrahedra with m = 3:
#   Solving with initial guess: v=0.64, r=0.27
#   ✓ Solution found:
#     v = 0.6396307857
#     r = 0.2500000006
#     y = 1.2792615714
#   Verification:
#     |close1| = 5.76e-09
#     |close2| = 1.18e-09
#   Kaleidocycle properties:
#     Constant torsion: mean(cos)=0.00000016, std=8.76e-08
#     Mean torsion angle: 90.0000°
#     Stationary: {'is_stationary': False, 'projected_gradient_norm': 0.3046630877167818, 'gradient_norm': 0.5773502636016729, 'constraint_penalty': 3.389951724089526e-13, 'details': {'energy': 'mean_cos', 'tolerance': 0.0001, 'finite_diff_step': 1e-08, 'n_constraints': 16, 'n_variables': 21, 'constraint_rank': 14, 'backend': 'default'}}
#
# N = 7 tetrahedra with m = 3:
#   Solving with initial guess: v=0.48, r=0.27
#   ✓ Solution found:
#     v = 0.4866323337
#     r = 0.2732433253
#     y = 1.1354754453
#   Verification:
#     |close1| = 9.93e-10
#     |close2| = 1.76e-11
#   Kaleidocycle properties:
#     Constant torsion: mean(cos)=0.29538865, std=3.05e-07
#     Mean torsion angle: 72.8192°
#     Stationary: {'is_stationary': False, 'projected_gradient_norm': 0.23185557337895277, 'gradient_norm': 0.4283735514132763, 'constraint_penalty': 2.6281433999191246e-12, 'details': {'energy': 'mean_cos', 'tolerance': 0.0001, 'finite_diff_step': 1e-08, 'n_constraints': 18, 'n_variables': 24, 'constraint_rank': 16, 'backend': 'default'}}
#
# N = 8 tetrahedra with m = 3:
#   Solving with initial guess: v=0.40, r=0.72
#   ✓ Solution found:
#     v = 0.3999817879
#     r = 0.7166217672
#     y = 1.0666181011
#   Verification:
#     |close1| = 5.07e-10
#     |close2| = 3.26e-13
#   Kaleidocycle properties:
#     Constant torsion: mean(cos)=-0.46995899, std=2.66e-07
#     Mean torsion angle: 118.0316°
#     Stationary: {'is_stationary': False, 'projected_gradient_norm': 0.18059028931983115, 'gradient_norm': 0.3360364138875451, 'constraint_penalty': 1.52310999721567e-12, 'details': {'energy': 'mean_cos', 'tolerance': 0.0001, 'finite_diff_step': 1e-08, 'n_constraints': 20, 'n_variables': 27, 'constraint_rank': 18, 'backend': 'default'}}
#
# N = 9 tetrahedra with m = 3:
#   Solving with initial guess: v=0.34, r=0.29
#   ✓ Solution found:
#     v = 0.3421943650
#     r = 0.2889929769
#     y = 1.0265830951
#   Verification:
#     |close1| = 6.67e-10
#     |close2| = 2.58e-10
#   Kaleidocycle properties:
#     Constant torsion: mean(cos)=0.58520346, std=3.39e-07
#     Mean torsion angle: 54.1826°
#     Stationary: {'is_stationary': False, 'projected_gradient_norm': 0.14311823657255993, 'gradient_norm': 0.266753413453885, 'constraint_penalty': 2.5791176032245e-12, 'details': {'energy': 'mean_cos', 'tolerance': 0.0001, 'finite_diff_step': 1e-08, 'n_constraints': 22, 'n_variables': 30, 'constraint_rank': 20, 'backend': 'default'}}
#
# N = 15 tetrahedra with m = 3:
#   Solving with initial guess: v=0.19, r=0.30
#   ✓ Solution found:
#     v = 0.1894063708
#     r = 0.2995618934
#     y = 0.9470318542
#   Verification:
#     |close1| = 8.43e-10
#     |close2| = 6.31e-10
#   Kaleidocycle properties:
#     Constant torsion: mean(cos)=0.85330499, std=5.38e-07
#     Mean torsion angle: 31.4270°
#     Stationary: {'is_stationary': False, 'projected_gradient_norm': 0.050881074545093434, 'gradient_norm': 0.08987216656371655, 'constraint_penalty': 8.083572485041248e-12, 'details': {'energy': 'mean_cos', 'tolerance': 0.0001, 'finite_diff_step': 1e-08, 'n_constraints': 34, 'n_variables': 48, 'constraint_rank': 32, 'backend': 'default'}}
#
# N = 15 tetrahedra with m = 5:
#   Solving with initial guess: v=0.40, r=0.69
#   ✓ Solution found:
#     v = 0.4011699507
#     r = 0.6886573371
#     y = 1.2035098520
#   Verification:
#     |close1| = 1.85e-09
#     |close2| = 2.26e-13
#   Kaleidocycle properties:
#     Constant torsion: mean(cos)=-0.64966319, std=7.98e-07
#     Mean torsion angle: 130.5162°
#     Stationary: {'is_stationary': False, 'projected_gradient_norm': 0.10364064666573633, 'gradient_norm': 0.22110397515945338, 'constraint_penalty': 7.892406185433967e-11, 'details': {'energy': 'mean_cos', 'tolerance': 0.0001, 'finite_diff_step': 1e-08, 'n_constraints': 34, 'n_variables': 48, 'constraint_rank': 32, 'backend': 'default'}}

# %% [markdown]
# ## Visualize

# %%
# Visualize kaleidocycles for N = 6, 8, 9, 13
fig = plt.figure(figsize=(20, 5))

for subplot_idx, (N,m,v,r,y) in enumerate(solutions, start=1):
        # Generate curve
        curve = generate_theta_curve(v, 0, r, y, N, t=0.0)
        kc = Kaleidocycle(curve=curve)
        info = kc.local_dof(return_basis=False)
        print(N,info)

        # Plot
        ax = fig.add_subplot(1, len(solutions), subplot_idx, projection='3d')
        kc.plot(ax=ax, title=f'N = {N} Tetrahedra\nv={v:.4f}, r={r:.4f}, y={y:.4f}')

plt.tight_layout()
plt.show()
# Out:
# 6 {'dof': 6, 'raw_dof': 7, 'rigid_dof': 3, 'rank': 14, 'n_constraints': 16, 'n_variables': 21, 'singular_values': array([3.68809537e+00, 3.62940447e+00, 3.19067974e+00, 2.32947018e+00,
#        2.00000001e+00, 2.00000001e+00, 2.00000001e+00, 1.81435846e+00,
#        1.50367950e+00, 1.49042175e+00, 1.41421357e+00, 1.37311883e+00,
#        1.04288905e+00, 9.33343221e-01, 6.37248188e-16, 3.21074556e-16]), 'tol': 1.719735527971459e-14}
# 7 {'dof': 7, 'raw_dof': 8, 'rigid_dof': 3, 'rank': 16, 'n_constraints': 18, 'n_variables': 24, 'singular_values': array([4.22244068e+00, 3.98383530e+00, 3.66239107e+00, 2.55549067e+00,
#        2.08195502e+00, 2.00552846e+00, 2.00000001e+00, 1.99033024e+00,
#        1.81477842e+00, 1.66385943e+00, 1.55916974e+00, 1.52225814e+00,
#        1.33645203e+00, 1.13664648e+00, 9.56213165e-01, 8.69998583e-01,
#        3.24559580e-16, 0.00000000e+00]), 'tol': 2.2501684139021928e-14}
# 8 {'dof': 8, 'raw_dof': 9, 'rigid_dof': 3, 'rank': 18, 'n_constraints': 20, 'n_variables': 27, 'singular_values': array([4.45121576e+00, 4.13682104e+00, 3.86392119e+00, 2.77776437e+00,
#        2.15944323e+00, 2.05530122e+00, 2.02317479e+00, 2.00504469e+00,
#        2.00000001e+00, 1.73566517e+00, 1.57401566e+00, 1.52172438e+00,
#        1.46099940e+00, 1.42943024e+00, 1.11207424e+00, 1.04234580e+00,
#        8.43757848e-01, 7.84142253e-01, 2.38043236e-16, 0.00000000e+00]), 'tol': 2.6685947991160282e-14}
# 9 {'dof': 9, 'raw_dof': 10, 'rigid_dof': 3, 'rank': 20, 'n_constraints': 22, 'n_variables': 30, 'singular_values': array([ 4.65322204e+00,  4.22963526e+00,  3.96430765e+00,  2.90200513e+00,
#         2.24822531e+00,  2.12487145e+00,  2.06966344e+00,  2.00915180e+00,
#         2.00000001e+00,  1.99697655e+00,  1.68307858e+00,  1.56597277e+00,
#         1.45079808e+00,  1.41099488e+00,  1.35120649e+00,  1.17026098e+00,
#         9.96240158e-01,  9.22547832e-01,  7.16365158e-01,  6.59755684e-01,
#         3.12411214e-16, -0.00000000e+00]), 'tol': 3.099668546968588e-14}
# 15 {'dof': 16, 'raw_dof': 16, 'rigid_dof': 3, 'rank': 32, 'n_constraints': 34, 'n_variables': 48, 'singular_values': array([5.81382457e+00, 4.14760079e+00, 3.95502813e+00, 2.93972030e+00,
#        2.55324855e+00, 2.44462432e+00, 2.42308019e+00, 2.32084879e+00,
#        2.27069874e+00, 2.17839666e+00, 2.12536508e+00, 2.06728019e+00,
#        2.06091549e+00, 2.02192962e+00, 2.00440437e+00, 2.00000001e+00,
#        1.62529891e+00, 1.53514507e+00, 1.11974896e+00, 1.05516501e+00,
#        9.79153116e-01, 9.33258393e-01, 8.84384454e-01, 8.19904395e-01,
#        7.37243096e-01, 6.75292640e-01, 5.81918141e-01, 5.20456465e-01,
#        4.29293393e-01, 3.70968280e-01, 2.84968060e-01, 2.54386403e-01,
#        4.61050592e-16, 5.78277157e-17]), 'tol': 6.196456218464085e-14}
# 15 {'dof': 15, 'raw_dof': 16, 'rigid_dof': 3, 'rank': 32, 'n_constraints': 34, 'n_variables': 48, 'singular_values': array([5.69911980e+00, 4.80309020e+00, 4.73700174e+00, 3.21403877e+00,
#        2.42228704e+00, 2.39006238e+00, 2.33733966e+00, 2.25856107e+00,
#        2.21799055e+00, 2.14171840e+00, 2.09912209e+00, 2.04605930e+00,
#        2.01838318e+00, 2.00345181e+00, 2.00000001e+00, 1.88721092e+00,
#        1.66900995e+00, 1.60809997e+00, 1.40718732e+00, 1.33549095e+00,
#        1.25931769e+00, 1.24397965e+00, 1.22772725e+00, 1.15201660e+00,
#        9.64305488e-01, 9.28555201e-01, 8.54406351e-01, 8.20091393e-01,
#        7.02883747e-01, 6.48449497e-01, 6.46988671e-01, 6.46051818e-01,
#        4.55088564e-16, 5.68085351e-17]), 'tol': 6.07420225656394e-14}
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Animated Visualization

# %%
from kaleidocycle import plot_band, constraint_penalty, ConstraintConfig, mean_cosine, export_csv
from matplotlib import animation

# Generate animation with theta functions
num_frames = 50
t_step = 0.05
z=0
N,m,v,r,y=solutions[5]
oriented = m % 2 == 0

frames = generate_animation_theta(v, z, r, y, N, num_frames, t_step, output="curve")
anim = KaleidocycleAnimation.from_curves(frames)

print(f"Generated {len(frames)} frames")
print(f"Each frame shape: {frames[0].shape}")
print(f"N, m, v, r, y = {N}, {m}, {v:.6f}, {r:.6f}, {y:.6f}")

f = plot_band(animation=anim)
plt.show()

# %%
anim.compute_scalar_property("penalty")

plt.close('all')
plt.plot(anim.scalar_properties["penalty"], marker='o')
plt.xlabel("Frame")
plt.ylabel("Penalty")
plt.title("Penalty Evolution")
plt.grid()
plt.show()
